# %%
path_to_model = "C:\\Users\\Abhijeet\\Documents\\GitHub\\dsba4152\\data\\e_mdm_20\\e_mdm"

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np

# %%
tf.__version__
# Out:
# '2.4.0'

# %%
model = keras.models.load_model(path_to_model)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# conv2d_input (InputLayer)       [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 254, 254, 256 2560        conv2d_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 254, 254, 256 0           conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 254, 254, 256 0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 127, 127, 128 295040      dropout[0][0]
# ...

# %%
path_to_img = "C:\\Users\\Abhijeet\\Documents\\GitHub\\dsba4152\\web"

# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread(path_to_img + "/image.png")

# %%
plt.imshow(img)

# %%
tensor_meta = tf.convert_to_tensor(np.array([0.5,0.5,0.5]).reshape((1,3)))
tensor_img = tf.convert_to_tensor(img[:,:,0].reshape((1,256,256)))

# %%
tensor_img.shape
# Out:
# TensorShape([1, 256, 256])

# %%
tensor_meta.shape
# Out:
# TensorShape([1, 3])

# %%
model.predict([tensor_meta , tensor_img])
# Out:
# array([[-0.44266987]], dtype=float32)

# %%
model.inputs[1]
# Out:
# <KerasTensor: shape=(None, 256, 256, 1) dtype=float32 (created by layer 'conv2d_input')>

# %%
model.layers

# %%
model.layers[1].input
# Out:
# <KerasTensor: shape=(None, 256, 256, 1) dtype=float32 (created by layer 'conv2d_input')>

# %%
from tensorflow.keras.models import Model
feature_model = Model(inputs=model.input[1], outputs=model.layers[1].output)
feature_maps = feature_model.predict(tensor_img)
feature_maps.shape
# Out:
# WARNING:tensorflow:8 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001D562E2D400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1, 254, 254, 256)

# %%
axs.shape
# Out:
# (2, 4)

# %%
np.max(feature_maps)
# Out:
# 0.17198788

# %%
#n_filters, ix = feature_maps.shape[-1], 1
n_filters , ix = 8 , 1
fig , axs = plt.subplots(2,4, figsize=(15,8))
vmin = np.min(feature_maps[0 , : , : , :n_filters ])
vmax = np.max(feature_maps[0 , : , : , :n_filters ])

for i in range(n_filters):
  # get the filter
    f = feature_maps[0, :, :, i]
    ax = axs[int(i/4)][i%4]
    # plot filter channel in grayscale
    ax.imshow(f,  vmin=vmin, vmax=vmax)
plt.savefig("output.png")

# %%
plt.imshow(feature_maps[0, :, :, 3] -  feature_maps[0, :, :, 0]  , cmap="gray")
